rsum = 0
tsum = sum(t_var)
for i, num in enumerate(t_var[:15]):
    rsum += num
    print(f'{i+1} \t \t | {rsum / tsum * 100}')
# Out:
# 	---temperature---
# # of EOFs 	 | % of total variance represented
# 1 	 	 | 97.69782451999872
# 2 	 	 | 99.01699475311736
# 3 	 	 | 99.62154010080997
# 4 	 	 | 99.81640468235699
# 5 	 	 | 99.90723010004227
# 6 	 	 | 99.94687669842732
# 7 	 	 | 99.96970545634561
# 8 	 	 | 99.98252148804787
# 9 	 	 | 99.9889849687404
# 10 	 	 | 99.99295046189177
# 11 	 	 | 99.99519003265144
# 12 	 	 | 99.99651239828712
# 13 	 	 | 99.9973874604874
# 14 	 	 | 99.99796046188956
# 15 	 	 | 99.99836750117389

# %%
print('\t---salinity')
print('# of EOFs \t | % of total variance represented')
rsum = 0
tsum = sum(s_var)
for i, num in enumerate(s_var[:15]):
    rsum += num
    print(f'{i+1} \t \t | {rsum / tsum * 100}')
# Out:
# 	---salinity
# # of EOFs 	 | % of total variance represented
# 1 	 	 | 99.9997991497839
# 2 	 	 | 99.99996489243365
# 3 	 	 | 99.99998473457559
# 4 	 	 | 99.99999302160812
# 5 	 	 | 99.99999724684264
# 6 	 	 | 99.99999851596624
# 7 	 	 | 99.99999912347822
# 8 	 	 | 99.99999936610774
# 9 	 	 | 99.99999956595069
# 10 	 	 | 99.99999970105542
# 11 	 	 | 99.99999977930266
# 12 	 	 | 99.99999983929692
# 13 	 	 | 99.99999987531861
# 14 	 	 | 99.99999990475614
# 15 	 	 | 99.99999992308733

# %% [markdown]
# ## plot

# %%
plt.scatter(x=np.arange(15), y=t_var[:15] / sum(t_var));
plt.ylabel('fraction of total variance')
plt.xlabel('EOF')
plt.title('Variances of each EOF of Temperature');

# %%
plt.scatter(x=np.arange(15), y=s_var[:15] / sum(s_var));
plt.ylabel('fraction of total variance')
plt.xlabel('EOF')
plt.title('Variances of each EOF of Salinity');

# %%
import pickle

with open('testing-notebooks/ut.pkl', 'rb') as f:
    U_t = pickle.load(f)

with open('testing-notebooks/us.pkl', 'rb') as f:
    U_s = pickle.load(f)

# %%
for i in range(5):
    plt.plot(np.arange(215), U_t[i][:215])
    plt.xlabel('Time (months)')
    plt.ylim(top=0.4, bottom=-0.4)
    plt.title(f'Temperature EOF {i+1}')
    plt.show()

# %%
for i in range(5):
    plt.plot(np.arange(215), U_t[i][:215])
plt.xlabel('Time (months)')
plt.legend(np.arange(5) + np.ones(5))
plt.ylim(top=0.4, bottom=-0.4)
plt.title(f'Temperature EOF 1-5')
plt.show()

# %%
for i in range(5):
    plt.plot(np.arange(215), U_s[i][:215])
    plt.xlabel('Time (months)')
    plt.ylim(top=0.4, bottom=-0.4)
    plt.title(f'Salinity EOF {i+1}')
    plt.show()

# %%
for i in range(5):
    plt.plot(np.arange(215), U_s[i][:215])
plt.xlabel('Time (months)')
plt.legend(np.arange(5) + np.ones(5))
plt.ylim(top=0.4, bottom=-0.4)
plt.title(f'Salinity EOF 1-5')
plt.show()
